# %%
import os
import h5py

def print_hdf5_structure(group, indent=0):
    """
    HDF5 Group 또는 File 객체를 넘기면
    하위 그룹/데이터셋 이름과 shape, dtype을 들여쓰기와 함께 출력합니다.
    """
    for key, item in group.items():
        prefix = "  " * indent
        if isinstance(item, h5py.Group):
            print(f"{prefix}{key}/")
            print_hdf5_structure(item, indent+1)
        else:  # Dataset
            print(f"{prefix}{key}  — dataset, shape={item.shape}, dtype={item.dtype}")

# %%
h5_dir = "./data/libero/libero_spatial/"
for filename in os.listdir(h5_dir):
    if not filename.endswith(".hdf5"):
        continue
    h5_path = os.path.join(h5_dir, filename)
    print(f"\n--- Structure of {filename} ---")
    with h5py.File(h5_path, "r") as f:
        print_hdf5_structure(f)
# Out:
# --- Structure of pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo.hdf5 ---
# data/
#   demo_0/
#     actions  — dataset, shape=(103, 7), dtype=float64
#     dones  — dataset, shape=(103,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(103, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(103, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(103, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(103, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(103, 3), dtype=float64
#       ee_pos  — dataset, shape=(103, 3), dtype=float64
#       ee_states  — dataset, shape=(103, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(103, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(103, 2), dtype=float64
#       joint_states  — dataset, shape=(103, 7), dtype=float64
#     rewards  — dataset, shape=(103,), dtype=uint8
#     robot_states  — dataset, shape=(103, 9), dtype=float64
#     states  — dataset, shape=(103, 92), dtype=float64
#   demo_1/
#     actions  — dataset, shape=(123, 7), dtype=float64
#     dones  — dataset, shape=(123,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(123, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(123, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(123, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(123, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(123, 3), dtype=float64
#       ee_pos  — dataset, shape=(123, 3), dtype=float64
#       ee_states  — dataset, shape=(123, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(123, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(123, 2), dtype=float64
#       joint_states  — dataset, shape=(123, 7), dtype=float64
#     rewards  — dataset, shape=(123,), dtype=uint8
#     robot_states  — dataset, shape=(123, 9), dtype=float64
#     states  — dataset, shape=(123, 92), dtype=float64
#   demo_10/
#     actions  — dataset, shape=(109, 7), dtype=float64
#     dones  — dataset, shape=(109,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(109, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(109, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(109, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(109, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(109, 3), dtype=float64
#       ee_pos  — dataset, shape=(109, 3), dtype=float64
#       ee_states  — dataset, shape=(109, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(109, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(109, 2), dtype=float64
#       joint_states  — dataset, shape=(109, 7), dtype=float64
#     rewards  — dataset, shape=(109,), dtype=uint8
#     robot_states  — dataset, shape=(109, 9), dtype=float64
#     states  — dataset, shape=(109, 92), dtype=float64
#   demo_11/
#     actions  — dataset, shape=(101, 7), dtype=float64
#     dones  — dataset, shape=(101,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(101, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(101, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(101, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(101, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(101, 3), dtype=float64
#       ee_pos  — dataset, shape=(101, 3), dtype=float64
#       ee_states  — dataset, shape=(101, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(101, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(101, 2), dtype=float64
#       joint_states  — dataset, shape=(101, 7), dtype=float64
#     rewards  — dataset, shape=(101,), dtype=uint8
#     robot_states  — dataset, shape=(101, 9), dtype=float64
#     states  — dataset, shape=(101, 92), dtype=float64
#   demo_12/
#     actions  — dataset, shape=(124, 7), dtype=float64
#     dones  — dataset, shape=(124,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(124, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(124, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(124, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(124, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(124, 3), dtype=float64
#       ee_pos  — dataset, shape=(124, 3), dtype=float64
#       ee_states  — dataset, shape=(124, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(124, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(124, 2), dtype=float64
#       joint_states  — dataset, shape=(124, 7), dtype=float64
#     rewards  — dataset, shape=(124,), dtype=uint8
#     robot_states  — dataset, shape=(124, 9), dtype=float64
#     states  — dataset, shape=(124, 92), dtype=float64
#   demo_13/
#     actions  — dataset, shape=(122, 7), dtype=float64
#     dones  — dataset, shape=(122,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(122, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(122, 3), dtype=float64
#       ee_pos  — dataset, shape=(122, 3), dtype=float64
#       ee_states  — dataset, shape=(122, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(122, 2), dtype=float64
#       joint_states  — dataset, shape=(122, 7), dtype=float64
#     rewards  — dataset, shape=(122,), dtype=uint8
#     robot_states  — dataset, shape=(122, 9), dtype=float64
#     states  — dataset, shape=(122, 92), dtype=float64
#   demo_14/
#     actions  — dataset, shape=(114, 7), dtype=float64
#     dones  — dataset, shape=(114,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(114, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(114, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(114, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(114, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(114, 3), dtype=float64
#       ee_pos  — dataset, shape=(114, 3), dtype=float64
#       ee_states  — dataset, shape=(114, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(114, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(114, 2), dtype=float64
#       joint_states  — dataset, shape=(114, 7), dtype=float64
#     rewards  — dataset, shape=(114,), dtype=uint8
#     robot_states  — dataset, shape=(114, 9), dtype=float64
#     states  — dataset, shape=(114, 92), dtype=float64
#   demo_15/
#     actions  — dataset, shape=(136, 7), dtype=float64
#     dones  — dataset, shape=(136,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(136, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(136, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(136, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(136, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(136, 3), dtype=float64
#       ee_pos  — dataset, shape=(136, 3), dtype=float64
#       ee_states  — dataset, shape=(136, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(136, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(136, 2), dtype=float64
#       joint_states  — dataset, shape=(136, 7), dtype=float64
#     rewards  — dataset, shape=(136,), dtype=uint8
#     robot_states  — dataset, shape=(136, 9), dtype=float64
#     states  — dataset, shape=(136, 92), dtype=float64
#   demo_16/
#     actions  — dataset, shape=(105, 7), dtype=float64
#     dones  — dataset, shape=(105,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(105, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(105, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(105, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(105, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(105, 3), dtype=float64
#       ee_pos  — dataset, shape=(105, 3), dtype=float64
#       ee_states  — dataset, shape=(105, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(105, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(105, 2), dtype=float64
#       joint_states  — dataset, shape=(105, 7), dtype=float64
#     rewards  — dataset, shape=(105,), dtype=uint8
#     robot_states  — dataset, shape=(105, 9), dtype=float64
#     states  — dataset, shape=(105, 92), dtype=float64
#   demo_17/
#     actions  — dataset, shape=(164, 7), dtype=float64
#     dones  — dataset, shape=(164,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(164, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(164, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(164, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(164, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(164, 3), dtype=float64
#       ee_pos  — dataset, shape=(164, 3), dtype=float64
#       ee_states  — dataset, shape=(164, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(164, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(164, 2), dtype=float64
#       joint_states  — dataset, shape=(164, 7), dtype=float64
#     rewards  — dataset, shape=(164,), dtype=uint8
#     robot_states  — dataset, shape=(164, 9), dtype=float64
#     states  — dataset, shape=(164, 92), dtype=float64
#   demo_18/
#     actions  — dataset, shape=(107, 7), dtype=float64
#     dones  — dataset, shape=(107,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(107, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(107, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(107, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(107, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(107, 3), dtype=float64
#       ee_pos  — dataset, shape=(107, 3), dtype=float64
#       ee_states  — dataset, shape=(107, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(107, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(107, 2), dtype=float64
#       joint_states  — dataset, shape=(107, 7), dtype=float64
#     rewards  — dataset, shape=(107,), dtype=uint8
#     robot_states  — dataset, shape=(107, 9), dtype=float64
#     states  — dataset, shape=(107, 92), dtype=float64
#   demo_19/
#     actions  — dataset, shape=(98, 7), dtype=float64
#     dones  — dataset, shape=(98,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(98, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(98, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(98, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(98, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(98, 3), dtype=float64
#       ee_pos  — dataset, shape=(98, 3), dtype=float64
#       ee_states  — dataset, shape=(98, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(98, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(98, 2), dtype=float64
#       joint_states  — dataset, shape=(98, 7), dtype=float64
#     rewards  — dataset, shape=(98,), dtype=uint8
#     robot_states  — dataset, shape=(98, 9), dtype=float64
#     states  — dataset, shape=(98, 92), dtype=float64
#   demo_2/
#     actions  — dataset, shape=(122, 7), dtype=float64
#     dones  — dataset, shape=(122,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(122, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(122, 3), dtype=float64
#       ee_pos  — dataset, shape=(122, 3), dtype=float64
#       ee_states  — dataset, shape=(122, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(122, 2), dtype=float64
#       joint_states  — dataset, shape=(122, 7), dtype=float64
#     rewards  — dataset, shape=(122,), dtype=uint8
#     robot_states  — dataset, shape=(122, 9), dtype=float64
#     states  — dataset, shape=(122, 92), dtype=float64
#   demo_20/
#     actions  — dataset, shape=(117, 7), dtype=float64
#     dones  — dataset, shape=(117,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(117, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(117, 3), dtype=float64
#       ee_pos  — dataset, shape=(117, 3), dtype=float64
#       ee_states  — dataset, shape=(117, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(117, 2), dtype=float64
#       joint_states  — dataset, shape=(117, 7), dtype=float64
#     rewards  — dataset, shape=(117,), dtype=uint8
#     robot_states  — dataset, shape=(117, 9), dtype=float64
#     states  — dataset, shape=(117, 92), dtype=float64
#   demo_21/
#     actions  — dataset, shape=(108, 7), dtype=float64
#     dones  — dataset, shape=(108,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(108, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(108, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(108, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(108, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(108, 3), dtype=float64
#       ee_pos  — dataset, shape=(108, 3), dtype=float64
#       ee_states  — dataset, shape=(108, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(108, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(108, 2), dtype=float64
#       joint_states  — dataset, shape=(108, 7), dtype=float64
#     rewards  — dataset, shape=(108,), dtype=uint8
#     robot_states  — dataset, shape=(108, 9), dtype=float64
#     states  — dataset, shape=(108, 92), dtype=float64
#   demo_22/
#     actions  — dataset, shape=(117, 7), dtype=float64
#     dones  — dataset, shape=(117,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(117, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(117, 3), dtype=float64
#       ee_pos  — dataset, shape=(117, 3), dtype=float64
#       ee_states  — dataset, shape=(117, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(117, 2), dtype=float64
#       joint_states  — dataset, shape=(117, 7), dtype=float64
#     rewards  — dataset, shape=(117,), dtype=uint8
#     robot_states  — dataset, shape=(117, 9), dtype=float64
#     states  — dataset, shape=(117, 92), dtype=float64
#   demo_23/
#     actions  — dataset, shape=(117, 7), dtype=float64
#     dones  — dataset, shape=(117,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(117, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(117, 3), dtype=float64
#       ee_pos  — dataset, shape=(117, 3), dtype=float64
#       ee_states  — dataset, shape=(117, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(117, 2), dtype=float64
#       joint_states  — dataset, shape=(117, 7), dtype=float64
#     rewards  — dataset, shape=(117,), dtype=uint8
#     robot_states  — dataset, shape=(117, 9), dtype=float64
#     states  — dataset, shape=(117, 92), dtype=float64
#   demo_24/
#     actions  — dataset, shape=(106, 7), dtype=float64
#     dones  — dataset, shape=(106,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(106, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(106, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(106, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(106, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(106, 3), dtype=float64
#       ee_pos  — dataset, shape=(106, 3), dtype=float64
#       ee_states  — dataset, shape=(106, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(106, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(106, 2), dtype=float64
#       joint_states  — dataset, shape=(106, 7), dtype=float64
#     rewards  — dataset, shape=(106,), dtype=uint8
#     robot_states  — dataset, shape=(106, 9), dtype=float64
#     states  — dataset, shape=(106, 92), dtype=float64
#   demo_25/
#     actions  — dataset, shape=(117, 7), dtype=float64
#     dones  — dataset, shape=(117,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(117, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(117, 3), dtype=float64
#       ee_pos  — dataset, shape=(117, 3), dtype=float64
#       ee_states  — dataset, shape=(117, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(117, 2), dtype=float64
#       joint_states  — dataset, shape=(117, 7), dtype=float64
#     rewards  — dataset, shape=(117,), dtype=uint8
#     robot_states  — dataset, shape=(117, 9), dtype=float64
#     states  — dataset, shape=(117, 92), dtype=float64
#   demo_26/
#     actions  — dataset, shape=(143, 7), dtype=float64
#     dones  — dataset, shape=(143,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(143, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(143, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(143, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(143, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(143, 3), dtype=float64
#       ee_pos  — dataset, shape=(143, 3), dtype=float64
#       ee_states  — dataset, shape=(143, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(143, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(143, 2), dtype=float64
#       joint_states  — dataset, shape=(143, 7), dtype=float64
#     rewards  — dataset, shape=(143,), dtype=uint8
#     robot_states  — dataset, shape=(143, 9), dtype=float64
#     states  — dataset, shape=(143, 92), dtype=float64
#   demo_27/
#     actions  — dataset, shape=(125, 7), dtype=float64
#     dones  — dataset, shape=(125,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(125, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(125, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(125, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(125, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(125, 3), dtype=float64
#       ee_pos  — dataset, shape=(125, 3), dtype=float64
#       ee_states  — dataset, shape=(125, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(125, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(125, 2), dtype=float64
#       joint_states  — dataset, shape=(125, 7), dtype=float64
#     rewards  — dataset, shape=(125,), dtype=uint8
#     robot_states  — dataset, shape=(125, 9), dtype=float64
#     states  — dataset, shape=(125, 92), dtype=float64
#   demo_28/
#     actions  — dataset, shape=(111, 7), dtype=float64
#     dones  — dataset, shape=(111,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(111, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(111, 3), dtype=float64
#       ee_pos  — dataset, shape=(111, 3), dtype=float64
#       ee_states  — dataset, shape=(111, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(111, 2), dtype=float64
#       joint_states  — dataset, shape=(111, 7), dtype=float64
#     rewards  — dataset, shape=(111,), dtype=uint8
#     robot_states  — dataset, shape=(111, 9), dtype=float64
#     states  — dataset, shape=(111, 92), dtype=float64
#   demo_29/
#     actions  — dataset, shape=(110, 7), dtype=float64
#     dones  — dataset, shape=(110,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(110, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(110, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(110, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(110, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(110, 3), dtype=float64
#       ee_pos  — dataset, shape=(110, 3), dtype=float64
#       ee_states  — dataset, shape=(110, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(110, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(110, 2), dtype=float64
#       joint_states  — dataset, shape=(110, 7), dtype=float64
#     rewards  — dataset, shape=(110,), dtype=uint8
#     robot_states  — dataset, shape=(110, 9), dtype=float64
#     states  — dataset, shape=(110, 92), dtype=float64
#   demo_3/
#     actions  — dataset, shape=(102, 7), dtype=float64
#     dones  — dataset, shape=(102,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(102, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(102, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(102, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(102, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(102, 3), dtype=float64
#       ee_pos  — dataset, shape=(102, 3), dtype=float64
#       ee_states  — dataset, shape=(102, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(102, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(102, 2), dtype=float64
#       joint_states  — dataset, shape=(102, 7), dtype=float64
#     rewards  — dataset, shape=(102,), dtype=uint8
#     robot_states  — dataset, shape=(102, 9), dtype=float64
#     states  — dataset, shape=(102, 92), dtype=float64
#   demo_30/
#     actions  — dataset, shape=(115, 7), dtype=float64
#     dones  — dataset, shape=(115,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(115, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(115, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(115, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(115, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(115, 3), dtype=float64
#       ee_pos  — dataset, shape=(115, 3), dtype=float64
#       ee_states  — dataset, shape=(115, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(115, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(115, 2), dtype=float64
#       joint_states  — dataset, shape=(115, 7), dtype=float64
#     rewards  — dataset, shape=(115,), dtype=uint8
#     robot_states  — dataset, shape=(115, 9), dtype=float64
#     states  — dataset, shape=(115, 92), dtype=float64
#   demo_31/
#     actions  — dataset, shape=(122, 7), dtype=float64
#     dones  — dataset, shape=(122,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(122, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(122, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(122, 3), dtype=float64
#       ee_pos  — dataset, shape=(122, 3), dtype=float64
#       ee_states  — dataset, shape=(122, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(122, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(122, 2), dtype=float64
#       joint_states  — dataset, shape=(122, 7), dtype=float64
#     rewards  — dataset, shape=(122,), dtype=uint8
#     robot_states  — dataset, shape=(122, 9), dtype=float64
#     states  — dataset, shape=(122, 92), dtype=float64
#   demo_32/
#     actions  — dataset, shape=(119, 7), dtype=float64
#     dones  — dataset, shape=(119,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(119, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(119, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(119, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(119, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(119, 3), dtype=float64
#       ee_pos  — dataset, shape=(119, 3), dtype=float64
#       ee_states  — dataset, shape=(119, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(119, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(119, 2), dtype=float64
#       joint_states  — dataset, shape=(119, 7), dtype=float64
#     rewards  — dataset, shape=(119,), dtype=uint8
#     robot_states  — dataset, shape=(119, 9), dtype=float64
#     states  — dataset, shape=(119, 92), dtype=float64
#   demo_33/
#     actions  — dataset, shape=(121, 7), dtype=float64
#     dones  — dataset, shape=(121,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(121, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(121, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(121, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(121, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(121, 3), dtype=float64
#       ee_pos  — dataset, shape=(121, 3), dtype=float64
#       ee_states  — dataset, shape=(121, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(121, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(121, 2), dtype=float64
#       joint_states  — dataset, shape=(121, 7), dtype=float64
#     rewards  — dataset, shape=(121,), dtype=uint8
#     robot_states  — dataset, shape=(121, 9), dtype=float64
#     states  — dataset, shape=(121, 92), dtype=float64
#   demo_34/
#     actions  — dataset, shape=(131, 7), dtype=float64
#     dones  — dataset, shape=(131,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(131, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(131, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(131, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(131, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(131, 3), dtype=float64
#       ee_pos  — dataset, shape=(131, 3), dtype=float64
#       ee_states  — dataset, shape=(131, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(131, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(131, 2), dtype=float64
#       joint_states  — dataset, shape=(131, 7), dtype=float64
#     rewards  — dataset, shape=(131,), dtype=uint8
#     robot_states  — dataset, shape=(131, 9), dtype=float64
#     states  — dataset, shape=(131, 92), dtype=float64
#   demo_35/
#     actions  — dataset, shape=(140, 7), dtype=float64
#     dones  — dataset, shape=(140,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(140, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(140, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(140, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(140, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(140, 3), dtype=float64
#       ee_pos  — dataset, shape=(140, 3), dtype=float64
#       ee_states  — dataset, shape=(140, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(140, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(140, 2), dtype=float64
#       joint_states  — dataset, shape=(140, 7), dtype=float64
#     rewards  — dataset, shape=(140,), dtype=uint8
#     robot_states  — dataset, shape=(140, 9), dtype=float64
#     states  — dataset, shape=(140, 92), dtype=float64
#   demo_36/
#     actions  — dataset, shape=(121, 7), dtype=float64
#     dones  — dataset, shape=(121,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(121, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(121, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(121, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(121, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(121, 3), dtype=float64
#       ee_pos  — dataset, shape=(121, 3), dtype=float64
#       ee_states  — dataset, shape=(121, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(121, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(121, 2), dtype=float64
#       joint_states  — dataset, shape=(121, 7), dtype=float64
#     rewards  — dataset, shape=(121,), dtype=uint8
#     robot_states  — dataset, shape=(121, 9), dtype=float64
#     states  — dataset, shape=(121, 92), dtype=float64
#   demo_37/
#     actions  — dataset, shape=(129, 7), dtype=float64
#     dones  — dataset, shape=(129,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(129, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(129, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(129, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(129, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(129, 3), dtype=float64
#       ee_pos  — dataset, shape=(129, 3), dtype=float64
#       ee_states  — dataset, shape=(129, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(129, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(129, 2), dtype=float64
#       joint_states  — dataset, shape=(129, 7), dtype=float64
#     rewards  — dataset, shape=(129,), dtype=uint8
#     robot_states  — dataset, shape=(129, 9), dtype=float64
#     states  — dataset, shape=(129, 92), dtype=float64
#   demo_38/
#     actions  — dataset, shape=(114, 7), dtype=float64
#     dones  — dataset, shape=(114,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(114, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(114, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(114, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(114, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(114, 3), dtype=float64
#       ee_pos  — dataset, shape=(114, 3), dtype=float64
#       ee_states  — dataset, shape=(114, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(114, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(114, 2), dtype=float64
#       joint_states  — dataset, shape=(114, 7), dtype=float64
#     rewards  — dataset, shape=(114,), dtype=uint8
#     robot_states  — dataset, shape=(114, 9), dtype=float64
#     states  — dataset, shape=(114, 92), dtype=float64
#   demo_39/
#     actions  — dataset, shape=(115, 7), dtype=float64
#     dones  — dataset, shape=(115,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(115, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(115, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(115, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(115, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(115, 3), dtype=float64
#       ee_pos  — dataset, shape=(115, 3), dtype=float64
#       ee_states  — dataset, shape=(115, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(115, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(115, 2), dtype=float64
#       joint_states  — dataset, shape=(115, 7), dtype=float64
#     rewards  — dataset, shape=(115,), dtype=uint8
#     robot_states  — dataset, shape=(115, 9), dtype=float64
#     states  — dataset, shape=(115, 92), dtype=float64
#   demo_4/
#     actions  — dataset, shape=(111, 7), dtype=float64
#     dones  — dataset, shape=(111,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(111, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(111, 3), dtype=float64
#       ee_pos  — dataset, shape=(111, 3), dtype=float64
#       ee_states  — dataset, shape=(111, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(111, 2), dtype=float64
#       joint_states  — dataset, shape=(111, 7), dtype=float64
#     rewards  — dataset, shape=(111,), dtype=uint8
#     robot_states  — dataset, shape=(111, 9), dtype=float64
#     states  — dataset, shape=(111, 92), dtype=float64
#   demo_40/
#     actions  — dataset, shape=(108, 7), dtype=float64
#     dones  — dataset, shape=(108,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(108, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(108, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(108, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(108, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(108, 3), dtype=float64
#       ee_pos  — dataset, shape=(108, 3), dtype=float64
#       ee_states  — dataset, shape=(108, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(108, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(108, 2), dtype=float64
#       joint_states  — dataset, shape=(108, 7), dtype=float64
#     rewards  — dataset, shape=(108,), dtype=uint8
#     robot_states  — dataset, shape=(108, 9), dtype=float64
#     states  — dataset, shape=(108, 92), dtype=float64
#   demo_41/
#     actions  — dataset, shape=(106, 7), dtype=float64
#     dones  — dataset, shape=(106,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(106, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(106, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(106, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(106, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(106, 3), dtype=float64
#       ee_pos  — dataset, shape=(106, 3), dtype=float64
#       ee_states  — dataset, shape=(106, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(106, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(106, 2), dtype=float64
#       joint_states  — dataset, shape=(106, 7), dtype=float64
#     rewards  — dataset, shape=(106,), dtype=uint8
#     robot_states  — dataset, shape=(106, 9), dtype=float64
#     states  — dataset, shape=(106, 92), dtype=float64
#   demo_42/
#     actions  — dataset, shape=(138, 7), dtype=float64
#     dones  — dataset, shape=(138,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(138, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(138, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(138, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(138, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(138, 3), dtype=float64
#       ee_pos  — dataset, shape=(138, 3), dtype=float64
#       ee_states  — dataset, shape=(138, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(138, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(138, 2), dtype=float64
#       joint_states  — dataset, shape=(138, 7), dtype=float64
#     rewards  — dataset, shape=(138,), dtype=uint8
#     robot_states  — dataset, shape=(138, 9), dtype=float64
#     states  — dataset, shape=(138, 92), dtype=float64
#   demo_43/
#     actions  — dataset, shape=(93, 7), dtype=float64
#     dones  — dataset, shape=(93,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(93, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(93, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(93, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(93, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(93, 3), dtype=float64
#       ee_pos  — dataset, shape=(93, 3), dtype=float64
#       ee_states  — dataset, shape=(93, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(93, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(93, 2), dtype=float64
#       joint_states  — dataset, shape=(93, 7), dtype=float64
#     rewards  — dataset, shape=(93,), dtype=uint8
#     robot_states  — dataset, shape=(93, 9), dtype=float64
#     states  — dataset, shape=(93, 92), dtype=float64
#   demo_44/
#     actions  — dataset, shape=(100, 7), dtype=float64
#     dones  — dataset, shape=(100,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(100, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(100, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(100, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(100, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(100, 3), dtype=float64
#       ee_pos  — dataset, shape=(100, 3), dtype=float64
#       ee_states  — dataset, shape=(100, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(100, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(100, 2), dtype=float64
#       joint_states  — dataset, shape=(100, 7), dtype=float64
#     rewards  — dataset, shape=(100,), dtype=uint8
#     robot_states  — dataset, shape=(100, 9), dtype=float64
#     states  — dataset, shape=(100, 92), dtype=float64
#   demo_45/
#     actions  — dataset, shape=(126, 7), dtype=float64
#     dones  — dataset, shape=(126,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(126, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(126, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(126, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(126, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(126, 3), dtype=float64
#       ee_pos  — dataset, shape=(126, 3), dtype=float64
#       ee_states  — dataset, shape=(126, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(126, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(126, 2), dtype=float64
#       joint_states  — dataset, shape=(126, 7), dtype=float64
#     rewards  — dataset, shape=(126,), dtype=uint8
#     robot_states  — dataset, shape=(126, 9), dtype=float64
#     states  — dataset, shape=(126, 92), dtype=float64
#   demo_46/
#     actions  — dataset, shape=(125, 7), dtype=float64
#     dones  — dataset, shape=(125,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(125, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(125, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(125, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(125, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(125, 3), dtype=float64
#       ee_pos  — dataset, shape=(125, 3), dtype=float64
#       ee_states  — dataset, shape=(125, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(125, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(125, 2), dtype=float64
#       joint_states  — dataset, shape=(125, 7), dtype=float64
#     rewards  — dataset, shape=(125,), dtype=uint8
#     robot_states  — dataset, shape=(125, 9), dtype=float64
#     states  — dataset, shape=(125, 92), dtype=float64
#   demo_47/
#     actions  — dataset, shape=(117, 7), dtype=float64
#     dones  — dataset, shape=(117,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(117, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(117, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(117, 3), dtype=float64
#       ee_pos  — dataset, shape=(117, 3), dtype=float64
#       ee_states  — dataset, shape=(117, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(117, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(117, 2), dtype=float64
#       joint_states  — dataset, shape=(117, 7), dtype=float64
#     rewards  — dataset, shape=(117,), dtype=uint8
#     robot_states  — dataset, shape=(117, 9), dtype=float64
#     states  — dataset, shape=(117, 92), dtype=float64
#   demo_48/
#     actions  — dataset, shape=(131, 7), dtype=float64
#     dones  — dataset, shape=(131,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(131, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(131, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(131, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(131, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(131, 3), dtype=float64
#       ee_pos  — dataset, shape=(131, 3), dtype=float64
#       ee_states  — dataset, shape=(131, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(131, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(131, 2), dtype=float64
#       joint_states  — dataset, shape=(131, 7), dtype=float64
#     rewards  — dataset, shape=(131,), dtype=uint8
#     robot_states  — dataset, shape=(131, 9), dtype=float64
#     states  — dataset, shape=(131, 92), dtype=float64
#   demo_49/
#     actions  — dataset, shape=(135, 7), dtype=float64
#     dones  — dataset, shape=(135,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(135, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(135, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(135, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(135, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(135, 3), dtype=float64
#       ee_pos  — dataset, shape=(135, 3), dtype=float64
#       ee_states  — dataset, shape=(135, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(135, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(135, 2), dtype=float64
#       joint_states  — dataset, shape=(135, 7), dtype=float64
#     rewards  — dataset, shape=(135,), dtype=uint8
#     robot_states  — dataset, shape=(135, 9), dtype=float64
#     states  — dataset, shape=(135, 92), dtype=float64
#   demo_5/
#     actions  — dataset, shape=(111, 7), dtype=float64
#     dones  — dataset, shape=(111,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(111, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(111, 3), dtype=float64
#       ee_pos  — dataset, shape=(111, 3), dtype=float64
#       ee_states  — dataset, shape=(111, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(111, 2), dtype=float64
#       joint_states  — dataset, shape=(111, 7), dtype=float64
#     rewards  — dataset, shape=(111,), dtype=uint8
#     robot_states  — dataset, shape=(111, 9), dtype=float64
#     states  — dataset, shape=(111, 92), dtype=float64
#   demo_6/
#     actions  — dataset, shape=(109, 7), dtype=float64
#     dones  — dataset, shape=(109,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(109, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(109, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(109, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(109, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(109, 3), dtype=float64
#       ee_pos  — dataset, shape=(109, 3), dtype=float64
#       ee_states  — dataset, shape=(109, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(109, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(109, 2), dtype=float64
#       joint_states  — dataset, shape=(109, 7), dtype=float64
#     rewards  — dataset, shape=(109,), dtype=uint8
#     robot_states  — dataset, shape=(109, 9), dtype=float64
#     states  — dataset, shape=(109, 92), dtype=float64
#   demo_7/
#     actions  — dataset, shape=(123, 7), dtype=float64
#     dones  — dataset, shape=(123,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(123, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(123, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(123, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(123, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(123, 3), dtype=float64
#       ee_pos  — dataset, shape=(123, 3), dtype=float64
#       ee_states  — dataset, shape=(123, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(123, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(123, 2), dtype=float64
#       joint_states  — dataset, shape=(123, 7), dtype=float64
#     rewards  — dataset, shape=(123,), dtype=uint8
#     robot_states  — dataset, shape=(123, 9), dtype=float64
#     states  — dataset, shape=(123, 92), dtype=float64
#   demo_8/
#     actions  — dataset, shape=(111, 7), dtype=float64
#     dones  — dataset, shape=(111,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(111, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(111, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(111, 3), dtype=float64
#       ee_pos  — dataset, shape=(111, 3), dtype=float64
#       ee_states  — dataset, shape=(111, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(111, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(111, 2), dtype=float64
#       joint_states  — dataset, shape=(111, 7), dtype=float64
#     rewards  — dataset, shape=(111,), dtype=uint8
#     robot_states  — dataset, shape=(111, 9), dtype=float64
#     states  — dataset, shape=(111, 92), dtype=float64
#   demo_9/
#     actions  — dataset, shape=(110, 7), dtype=float64
#     dones  — dataset, shape=(110,), dtype=uint8
#     obs/
#       agentview_rgb  — dataset, shape=(110, 128, 128, 3), dtype=uint8
#       clip_patch_features  — dataset, shape=(110, 256, 768), dtype=float32
#       clip_patch_features_gripper  — dataset, shape=(110, 256, 768), dtype=float32
#       clip_text_features  — dataset, shape=(110, 15, 768), dtype=float32
#       ee_ori  — dataset, shape=(110, 3), dtype=float64
#       ee_pos  — dataset, shape=(110, 3), dtype=float64
#       ee_states  — dataset, shape=(110, 6), dtype=float64
#       eye_in_hand_rgb  — dataset, shape=(110, 128, 128, 3), dtype=uint8
#       gripper_states  — dataset, shape=(110, 2), dtype=float64
#       joint_states  — dataset, shape=(110, 7), dtype=float64
#     rewards  — dataset, shape=(110,), dtype=uint8
#     robot_states  — dataset, shape=(110, 9), dtype=float64
#     states  — dataset, shape=(110, 92), dtype=float64

# %%
f = h5py.File(h5_path, "r")

for i in range (4):
    print(f['data']['demo_0']['actions'][i])
# Out:
# [ 0.02410714  0.         -0.          0.          0.         -0.
#  -1.        ]
# [ 0.12053571  0.         -0.          0.          0.         -0.00428571
#  -1.        ]
# [ 0.24107143  0.06964286  0.00535714  0.          0.         -0.01071429
#  -1.        ]
# [ 0.38035714  0.13660714  0.01875    -0.01178571  0.         -0.
#  -1.        ]

# %%
for i in range (4):
    print(f['data']['demo_0']['obs']['gripper_states'][i])
# Out:
# [ 0.03623153 -0.03622648]
# [ 0.03745265 -0.03744702]
# [ 0.03814649 -0.03811981]
# [ 0.03853856 -0.03849153]

# %%
for i in range (4):
    print(f['data']['demo_0']['obs']['joint_states'][i])
# Out:
# [-2.30867973e-03 -1.40420283e-01 -2.07154584e-03 -2.42213379e+00
#   3.88517261e-03  2.22705656e+00  7.88595549e-01]
# [-2.30881708e-03 -1.38837628e-01 -2.09673764e-03 -2.42109365e+00
#   3.89131664e-03  2.22903541e+00  7.88737377e-01]
# [-2.11526190e-03 -1.34767382e-01 -1.54088569e-03 -2.41823845e+00
#   4.34006992e-03  2.23335005e+00  7.89645938e-01]
# [-1.55999879e-03 -1.27470420e-01  2.63087157e-04 -2.41265511e+00
#   4.41268091e-03  2.23982176e+00  7.91829208e-01]

# %%
for i in range (4):
    print(f['data']['demo_0']['obs/ee_states'][i])
# Out:
# [-2.00980515e-01 -1.56247559e-03  1.17337999e+00  3.14372893e+00
#  -1.49478438e-02 -8.59467059e-02]
# [-2.00302798e-01 -1.57771939e-03  1.17325063e+00  3.14378502e+00
#  -1.52103992e-02 -8.37810226e-02]
# [-1.98610107e-01 -1.22803272e-03  1.17292346e+00  3.14410753e+00
#  -1.59105747e-02 -7.90093983e-02]
# [-1.95633882e-01 -1.95319328e-04  1.17241631e+00  3.14402444e+00
#  -1.58277862e-02 -7.16237257e-02]

# %%
for i in range (4):
    print(f['data']['demo_0']['robot_states'][i]) ## gripper_states + ee_states
# Out:
# [ 0.03623153 -0.03622648 -0.20098052 -0.00156248  1.17337999  0.99961381
#  -0.00475298 -0.02732854 -0.00167321]
# [ 0.03745265 -0.03744702 -0.2003028  -0.00157772  1.17325063  0.99963199
#  -0.00483646 -0.02663992 -0.00167266]
# [ 0.03814649 -0.03811981 -0.19861011 -0.00122803  1.17292346  0.99967004
#  -0.00505877 -0.02512106 -0.00177384]
# [ 3.85385575e-02 -3.84915250e-02 -1.95633882e-01 -1.95319328e-04
#   1.17241631e+00  9.99726604e-01 -5.03286766e-03 -2.27746779e-02
#  -1.64366956e-03]

# %%
if "libero" in self.data_sources:
            print("Libero")
            self.files = {}
            self.episodes = []

            for task in tasks:
                task_dir = os.path.join(self.dataset_path, task)
                if not os.path.isdir(task_dir):
                    continue
                for fname in os.listdir(task_dir):
                    if not fname.endswith('.hdf5'):
                        continue
                    lang_inst = os.path.splitext(fname)[0]
                    path = os.path.join(task_dir, fname)
                    hf = h5py.File(path, 'r')
                    self.files[(task, lang_inst)] = hf

                    for demo in hf['data']:
                        ep_group = f"data/{demo}"
                        self.episodes.append((task, lang_inst, ep_group))

# %%
episodes = []
files = {}
h5_dir = "./data/libero/libero_spatial/"

for fname in os.listdir(h5_dir):
    lang_inst = os.path.splitext(fname)[0]
    path = os.path.join(h5_dir, fname)
    hf = h5py.File(path, 'r')['data']
    files[(1, lang_inst)] = hf

    for demo in hf:
        ep_group = f"{demo}"
        episodes.append((1, lang_inst, ep_group))

# %%
episodes
# Out:
# [(1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_0'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_1'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_10'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_11'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_12'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_13'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_14'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_15'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_16'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_17'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_18'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_19'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_2'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_20'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_21'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_22'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_23'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_24'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_25'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_26'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_27'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_28'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_29'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_3'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_30'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_31'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_32'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_33'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_34'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_35'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_36'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_37'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_38'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_39'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_4'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_40'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_41'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_42'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_43'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_44'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_45'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_46'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_47'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_48'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_49'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_5'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_6'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_7'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_8'),
#  (1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo',
#   'demo_9')]

# %%
files
# Out:
# {(1,
#   'pick_up_the_black_bowl_from_table_center_and_place_it_on_the_plate_demo'): <HDF5 group "/data" (50 members)>}
